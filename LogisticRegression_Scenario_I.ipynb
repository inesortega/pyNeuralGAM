# %% [markdown]
# # Running Neural GAM - Logistic regression
#
# 1. Install requirements
# 2. Load data
# 3. Train NeuralGAM
# 4. Visualize partial dependence plots

# %%
import sys
# !{sys.executable} -m pip install -q -r ../requirements.txt
# Out:
# WARNING: You are using pip version 20.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\iortega\repo\Neural_GAM\win-env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from src.NeuralGAM.ngam import NeuralGAM, plot_partial_dependencies
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 11
#       9 import pandas as pd
#      10 from sklearn.metrics import mean_squared_error
# ---> 11 from src.NeuralGAM.ngam import NeuralGAM, plot_partial_dependencies
#      12 import pandas as pd
#
# ModuleNotFoundError: No module named 'src.NeuralGAM'

# %% [markdown]
# Define the number of units of the Neural Network. For this example, we will use a *shallow* neural network with a single hidden layer with 1024 units. We can also define the learning rate for the Neural Network training.

# %%
units = 1024
learning_rate = 0.0053

output_path = "./results"
input_path = "./dataset/Scenario_I/uniform_binomial/"
# Create results directory
if not os.path.exists(output_path):
    os.makedirs(output_path)


input_path = os.path.normpath(os.path.abspath(os.path.join("./", input_path)))

# %% [markdown]
# Load dataset into Pandas Dataframes. If you want to preprocess or select some features, do it here. Our synthetic dataset is composed of train and test files, which we load separately.

# %%
X_train = pd.read_csv(os.path.join(input_path, "X_train.csv"), index_col=0).reset_index(drop=True)
y_train = pd.read_csv(os.path.join(input_path, "y_train.csv"), index_col=0).reset_index(drop=True).squeeze()
fs_train = pd.read_csv(os.path.join(input_path, "fs_train.csv"), index_col=0).reset_index(drop=True)
# center theoretical fs for plotting
fs_train = fs_train - fs_train.mean()

X_test = pd.read_csv(os.path.join(input_path, "X_test.csv"), index_col=0).reset_index(drop=True)
y_test = pd.read_csv(os.path.join(input_path, "y_test.csv"), index_col=0).reset_index(drop=True).squeeze()
fs_test = pd.read_csv(os.path.join(input_path, "fs_test.csv"), index_col=0).reset_index(drop=True)
# center theoretical fs for plotting
fs_test = fs_test - fs_test.mean()

# %% [markdown]
# Create and Train NeuralGAM instance of Gaussian Family.

# %%
ngam = NeuralGAM(num_inputs = len(X_train.columns), family="binomial", num_units=units, learning_rate=learning_rate)

muhat, fs_train_estimated, eta = ngam.fit(X_train = X_train, 
                                y_train = y_train, 
                                max_iter_ls = 10, 
                                bf_threshold=10e-5,
                                ls_threshold=0.1,
                                max_iter_backfitting=10)
# Out:
# Fitting GAM
#  -- max_it = 10
#  -- max_iter_backfitting = 10
#  -- ls_threshold = 0.1
#  -- bf_threshold=0.0001
#  -- learning_rate=0.001
#
#
# Iter Local Scoring 1
# 766/766 [==============================] - 4s 3ms/step - loss: 0.1282
# 766/766 [==============================] - 2s 2ms/step
# 552/766 [====================>.........] - ETA: 0s - loss: 0.0231
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 ngam = NeuralGAM(num_inputs = len(X_train.columns), family="binomial", num_units=units, learning_rate=learning_rate)
# ----> 3 muhat, fs_train_estimated, eta = ngam.fit(X_train = X_train,
#       4                                 y_train = y_train,
#       5                                 max_iter_ls = 10,
#       6                                 bf_threshold=10e-5,
#       7                                 ls_threshold=0.1,
#       8                                 max_iter_backfitting=10)
#
# File c:\Users\iortega\repo\Neural_GAM\src\NeuralGAM\ngam.py:143, in NeuralGAM.fit(self, X_train, y_train, max_iter_ls, w_train, bf_threshold, ls_threshold, max_iter_backfitting)
#     139 if self._family == "binomial":
#     140     self.feature_networks[k].compile(loss= "mean_squared_error",
#     141                                     optimizer="adam",
#     142                                     loss_weights= pd.Series(W))
# --> 143 self.feature_networks[k].fit(X_train[X_train.columns[k]],
#     144                              residuals,
#     145                              epochs=1,
#     146                              sample_weight = pd.Series(W) if self._family == "binomial" else None)
#     147 # Update f with current learned function for predictor k
#     148 f[index[k]] = self.feature_networks[k].predict(X_train[X_train.columns[k]])
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\keras\engine\training.py:1401, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1399 with data_handler.catch_stop_iteration():
#    1400   data_handler._initial_step = self._maybe_load_initial_step_from_ckpt()  # pylint: disable=protected-access
# -> 1401   for step in data_handler.steps():
#    1402     with tf.profiler.experimental.Trace(
#    1403         'train',
#    1404         epoch_num=epoch,
#    1405         step_num=step,
#    1406         batch_size=batch_size,
#    1407         _r=1):
#    1408       callbacks.on_train_batch_begin(step)
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\keras\engine\data_adapter.py:1248, in DataHandler.steps(self)
#    1246 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1247   break
# -> 1248 original_spe = self._steps_per_execution.numpy().item()
#    1249 can_run_full_execution = (
#    1250     original_spe == 1 or
#    1251     self._inferred_steps is None or
#    1252     self._inferred_steps - self._current_step >=
#    1253     original_spe)
#    1255 if can_run_full_execution:
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:715, in BaseResourceVariable.read_value(self)
#     712   value = self._read_variable_op()
#     713 # Return an identity so it can get placed on whatever device the context
#     714 # specifies instead of the device where the variable is.
# --> 715 return array_ops.identity(value)
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\ops\array_ops.py:295, in identity(input, name)
#     291 if context.executing_eagerly() and not hasattr(input, "graph"):
#     292   # Make sure we get an input with handle data attached from resource
#     293   # variables. Variables have correct handle data when graph building.
#     294   input = ops.convert_to_tensor(input)
# --> 295 ret = gen_array_ops.identity(input, name=name)
#     296 # Propagate handle data for happier shape inference for resource variables.
#     297 if hasattr(input, "_handle_data"):
#
# File c:\Users\iortega\repo\Neural_GAM\win-env\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4063, in identity(input, name)
#    4061 if tld.is_eager:
#    4062   try:
# -> 4063     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    4064       _ctx, "Identity", name, input)
#    4065     return _result
#    4066   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Once we trained the model, we can visualize the learnt partial effects from the training set. In this case, we will use an auxiliary function that allows us to plot both the original (theretical) functions and the learnt partial effect from the training set

# %%
from src.utils.utils import experiments_plot_partial_dependencies
experiments_plot_partial_dependencies(x_list=[X_train, X_train], f_list=[fs_train, fs_train_estimated], legends=["true", "estimated"], title="Learnt Training Partial Effects")

# %% [markdown]
# We can also compute the MSE between the theoretical and estimated response function:

# %%
mean_squared_error(y_train, muhat)
# Out:
# 0.2727089886919835
